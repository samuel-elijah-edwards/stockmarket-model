# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Collecting yfinance==0.2.32
#   Downloading yfinance-0.2.32-py2.py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 17.3 MB/s eta 0:00:00
# Collecting newspaper3k
#   Downloading newspaper3k-0.2.8-py3-none-any.whl (211 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 kB 41.2 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.9.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from yfinance==0.2.32->-r ./requirements.txt (line 1)) (4.9.1)
# Requirement already satisfied: numpy>=1.16.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from yfinance==0.2.32->-r ./requirements.txt (line 1)) (1.23.4)
# Collecting appdirs>=1.4.4
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting peewee>=3.16.2
#   Downloading peewee-3.17.0.tar.gz (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 80.8 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pandas>=1.3.0
#   Downloading pandas-2.1.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 74.2 MB/s eta 0:00:00
# Collecting html5lib>=1.1
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 26.3 MB/s eta 0:00:00
# Collecting requests>=2.31
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 13.2 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from yfinance==0.2.32->-r ./requirements.txt (line 1)) (4.11.1)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: pytz>=2022.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from yfinance==0.2.32->-r ./requirements.txt (line 1)) (2022.5)
# Collecting frozendict>=2.3.4
#   Downloading frozendict-2.3.10-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 18.7 MB/s eta 0:00:00
# Collecting tinysegmenter==0.3
#   Downloading tinysegmenter-0.3.tar.gz (16 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting PyYAML>=3.11
#   Downloading PyYAML-6.0.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (738 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 738.9/738.9 kB 53.4 MB/s eta 0:00:00
# Requirement already satisfied: nltk>=3.2.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from newspaper3k->-r ./requirements.txt (line 2)) (3.7)
# Collecting feedfinder2>=0.0.4
#   Downloading feedfinder2-0.0.4.tar.gz (3.3 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting jieba3k>=0.35.1
#   Downloading jieba3k-0.35.1.zip (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 65.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: python-dateutil>=2.5.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from newspaper3k->-r ./requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: cssselect>=0.9.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from newspaper3k->-r ./requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: tldextract>=2.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from newspaper3k->-r ./requirements.txt (line 2)) (3.4.0)
# Collecting feedparser>=5.2.1
#   Downloading feedparser-6.0.10-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 17.3 MB/s eta 0:00:00
# Requirement already satisfied: Pillow>=3.3.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from newspaper3k->-r ./requirements.txt (line 2)) (9.2.0)
# Requirement already satisfied: soupsieve>1.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from beautifulsoup4>=4.11.1->yfinance==0.2.32->-r ./requirements.txt (line 1)) (2.3.2.post1)
# Requirement already satisfied: six in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from feedfinder2>=0.0.4->newspaper3k->-r ./requirements.txt (line 2)) (1.16.0)
# Collecting sgmllib3k
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: webencodings in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from html5lib>=1.1->yfinance==0.2.32->-r ./requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk>=3.2.1->newspaper3k->-r ./requirements.txt (line 2)) (2022.9.13)
# Requirement already satisfied: tqdm in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk>=3.2.1->newspaper3k->-r ./requirements.txt (line 2)) (4.64.1)
# Requirement already satisfied: click in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk>=3.2.1->newspaper3k->-r ./requirements.txt (line 2)) (8.1.3)
# Requirement already satisfied: joblib in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk>=3.2.1->newspaper3k->-r ./requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: tzdata>=2022.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas>=1.3.0->yfinance==0.2.32->-r ./requirements.txt (line 1)) (2022.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests>=2.31->yfinance==0.2.32->-r ./requirements.txt (line 1)) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests>=2.31->yfinance==0.2.32->-r ./requirements.txt (line 1)) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests>=2.31->yfinance==0.2.32->-r ./requirements.txt (line 1)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests>=2.31->yfinance==0.2.32->-r ./requirements.txt (line 1)) (1.26.12)
# Requirement already satisfied: filelock>=3.0.8 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tldextract>=2.0.1->newspaper3k->-r ./requirements.txt (line 2)) (3.8.0)
# Requirement already satisfied: requests-file>=1.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tldextract>=2.0.1->newspaper3k->-r ./requirements.txt (line 2)) (1.5.1)
# Building wheels for collected packages: tinysegmenter, feedfinder2, jieba3k, peewee, sgmllib3k
#   Building wheel for tinysegmenter (setup.py): started
#   Building wheel for tinysegmenter (setup.py): finished with status 'done'
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13553 sha256=87bbcd5f4abec78b1aeed93b36f94cf81230d28a753ba7bf714cfa903f23935f
#   Stored in directory: /root/.cache/pip/wheels/94/ad/df/a2a01300cea47d5695f242f7e925a805970106fd9e4b151468
#   Building wheel for feedfinder2 (setup.py): started
#   Building wheel for feedfinder2 (setup.py): finished with status 'done'
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3356 sha256=34070a30cd4ce6eddb2d74c2e6280ebb05419906f31640dcd6a33c0b95ebc4b1
#   Stored in directory: /root/.cache/pip/wheels/43/4a/c2/61a371b2524ac90805391c660d8dc4505705297f25e2b85a5d
#   Building wheel for jieba3k (setup.py): started
#   Building wheel for jieba3k (setup.py): finished with status 'done'
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-py3-none-any.whl size=7398404 sha256=5895cbddbcc9509932dc8da7e970a63f43d020dbfcd6c58eaffb5d02610c778f
#   Stored in directory: /root/.cache/pip/wheels/c2/22/59/8214a8d6357e9f540ce1f37f9a4362b6156b4ca81b37f1945f
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.17.0-py3-none-any.whl size=135721 sha256=4b8f941e89c65eb978e26623db11e4f2252787c59209a92fec54cb6b4f915ff9
#   Stored in directory: /root/.cache/pip/wheels/77/6b/dc/722aee2a5d46a021ab67564c9d3d5536c3bd9577fcdc3a5aeb
#   Building wheel for sgmllib3k (setup.py): started
#   Building wheel for sgmllib3k (setup.py): finished with status 'done'
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6067 sha256=d15a55ca66f4e5058b354f0f9c888661be2d60f3e713b29af2e25666e06060a5
#   Stored in directory: /root/.cache/pip/wheels/65/7a/a7/78c287f64e401255dff4c13fdbc672fed5efbfd21c530114e1
# Successfully built tinysegmenter feedfinder2 jieba3k peewee sgmllib3k
# Installing collected packages: tinysegmenter, sgmllib3k, peewee, multitasking, jieba3k, appdirs, requests, PyYAML, html5lib, frozendict, feedparser, pandas, feedfinder2, yfinance, newspaper3k
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.1
#     Not uninstalling requests at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'requests'. No files were found to uninstall.
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.2.5
#     Not uninstalling pandas at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'pandas'. No files were found to uninstall.
# Successfully installed PyYAML-6.0.1 appdirs-1.4.4 feedfinder2-0.0.4 feedparser-6.0.10 frozendict-2.3.10 html5lib-1.1 jieba3k-0.35.1 multitasking-0.0.11 newspaper3k-0.2.8 pandas-2.1.3 peewee-3.17.0 requests-2.31.0 sgmllib3k-1.0.0 tinysegmenter-0.3 yfinance-0.2.32
#
# [notice] A new release of pip is available: 23.0.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=f86dace4-c215-40df-9ea2-a63cc39cfa4f' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
